# %%
import pandas as pd

# %%
data = pd.read_csv('maps_google_scraped_final_dataset_V5.csv')
data.columns
# Out:
# Index(['Unnamed: 0', 'searchString', 'title', 'categoryName', 'address',
#        'street', 'city', 'postalCode', 'claimThisBusiness', 'location',
#        'totalScore', 'temporarilyClosed', 'placeId', 'categories', 'cid',
#        'reviewsCount', 'reviewsDistribution', 'openingHours', 'url', 'coords',
#        'neigbourhood'],
#       dtype='object')

# %%
data = data.drop('Unnamed: 0', axis= 1)
#data = data.set_index('placeId')
data
# Out:
#      searchString                 title  categoryName  \
# 0         kavárna    Kavárna U Šimpanze   Coffee shop
# 1         kavárna                coffee   Coffee shop
# 2         kavárna              Křupkafé   Coffee shop
# 3         kavárna      Kavárna Dallmayr          Cafe
# 4         kavárna        Kafe a slanina   Coffee shop
# ..            ...                   ...           ...
# 424   coffee shop              Ema Cafe   Coffee shop
# 425   coffee shop  tyjátr coffee & wine   Coffee shop
# 426   coffee shop      Kinokavárna Brno   Coffee shop
# 427  espresso bar      Patio Café & Bar  Espresso bar
# 428  espresso bar  OC Nosreti - Café 52  Espresso bar
#
#                                                address  \
# 0                         635 00, Brno-Bystrc, Czechia
# 1    U Zoologické zahrady 46, 635 00 Brno-Bystrc, C...
# 2    U Zoologické zahrady 147, 664 71 Brno-Bystrc, ...
# 3    621 00, Hradecká 408/40, 621 00 Brno-Ivanovice...
# 4    Böhmova 13, 621 00 Brno-Řečkovice a Mokrá Hora...
# ..                                                 ...
# 424           Husova 167/7, 602 00 Brno-střed, Czechia
# 425             Husova 14a, 602 00 Brno-střed, Czechia
# 426            nám. SNP 33, 613 00 Brno-sever, Czechia
# 427              Husova 8A, 602 00 Brno-střed, Czechia
# 428         Křenová 409/52, 602 00 Brno-střed, Czechia
#
#                        street                         city postalCode  \
# 0                      635 00                  Brno-Bystrc        NaN
# 1     U Zoologické zahrady 46                  Brno-Bystrc     635 00
# 2    U Zoologické zahrady 147                  Brno-Bystrc     664 71
# 3     621 00, Hradecká 408/40               Brno-Ivanovice     621 00
# 4                  Böhmova 13  Brno-Řečkovice a Mokrá Hora     621 00
# ..                        ...                          ...        ...
# 424              Husova 167/7                   Brno-střed     602 00
# 425                Husova 14a                   Brno-střed     602 00
# 426               nám. SNP 33                   Brno-sever     613 00
# 427                 Husova 8A                   Brno-střed     602 00
# 428            Křenová 409/52                   Brno-střed     602 00
#
#      claimThisBusiness                                location  totalScore  \
# 0                 True  {'lat': 49.2305035, 'lng': 16.5337673}         5.0
# 1                 True  {'lat': 49.2333335, 'lng': 16.5308843}         1.0
# 2                False  {'lat': 49.2339446, 'lng': 16.5343742}         4.8
# 3                 True  {'lat': 49.2609078, 'lng': 16.5798162}         3.4
# 4                False  {'lat': 49.2452964, 'lng': 16.5818784}         4.8
# ..                 ...                                     ...         ...
# 424              False  {'lat': 49.1925629, 'lng': 16.6048872}         4.8
# 425              False  {'lat': 49.1943746, 'lng': 16.6047935}         4.9
# 426              False   {'lat': 49.217818, 'lng': 16.6207745}         3.8
# 427              False  {'lat': 49.1932345, 'lng': 16.6052392}         5.0
# 428               True  {'lat': 49.1909134, 'lng': 16.6222443}         4.3
#
#      temporarilyClosed                      placeId  \
# 0                False  ChIJe8xi1c-WEkcRZHdDHuo3j90
# 1                False  ChIJowGU1lKXEkcRhurHt6Lp8WA
# 2                False  ChIJhYGFpheXEkcRajb-rh-zrNw
# 3                False  ChIJObMrvW-REkcRVzYBCe8TIb0
# 4                False  ChIJwamoDsSREkcR9p9fj5gJeFs
# ..                 ...                          ...
# 424              False  ChIJe_ylhAKVEkcR7s1u0ojXXlU
# 425               True  ChIJS6BBUcaVEkcR4ZT1jabPeMo
# 426              False  ChIJLxTYoHuUEkcRy8XHNLCvtIY
# 427              False  ChIJj5cikNKVEkcRiukU7AjL2ow
# 428               True  ChIJS0FEsvmVEkcR9zM01uPpfjc
#
#                                          categories           cid  \
# 0                                   ['Coffee shop']  1.596504e+19
# 1                                   ['Coffee shop']  6.985621e+18
# 2                                   ['Coffee shop']  1.590128e+19
# 3                                          ['Cafe']  1.362820e+19
# 4                                   ['Coffee shop']  6.591029e+18
# ..                                              ...           ...
# 424            ['Coffee shop', 'Cake shop', 'Deli']  6.151591e+18
# 425        ['Coffee shop', 'Gastropub', 'Wine bar']  1.458964e+19
# 426  ['Coffee shop', 'Restaurant', 'Movie theater']  9.706576e+18
# 427                                ['Espresso bar']  1.014965e+19
# 428                                ['Espresso bar']  3.998891e+18
#
#      reviewsCount                                reviewsDistribution  \
# 0               1  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# 1               1  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# 2              16  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# 3              15  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# 4             149  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# ..            ...                                                ...
# 424            61  {'oneStar': 0, 'twoStar': 1, 'threeStar': 1, '...
# 425            25  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# 426           546  {'oneStar': 53, 'twoStar': 35, 'threeStar': 10...
# 427            17  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# 428            15  {'oneStar': 2, 'twoStar': 0, 'threeStar': 0, '...
#
#                                           openingHours  \
# 0    [{'day': 'Monday', 'hours': '10\u202fAM to 6\u...
# 1                                                   []
# 2    [{'day': 'Monday', 'hours': 'Closed'}, {'day':...
# 3    [{'day': 'Monday', 'hours': '8:30\u202fAM to 8...
# 4    [{'day': 'Monday', 'hours': '8\u202fAM to 6\u2...
# ..                                                 ...
# 424  [{'day': 'Thursday', 'hours': '6:30\u202fAM to...
# 425                                                 []
# 426  [{'day': 'Thursday', 'hours': '11\u202fAM to 1...
# 427  [{'day': 'Thursday', 'hours': '2 to 9\u202fPM'...
# 428                                                 []
#
#                                                    url  \
# 0    https://www.google.com/maps/search/?api=1&quer...
# 1    https://www.google.com/maps/search/?api=1&quer...
# 2    https://www.google.com/maps/search/?api=1&quer...
# 3    https://www.google.com/maps/search/?api=1&quer...
# 4    https://www.google.com/maps/search/?api=1&quer...
# ..                                                 ...
# 424  https://www.google.com/maps/search/?api=1&quer...
# 425  https://www.google.com/maps/search/?api=1&quer...
# 426  https://www.google.com/maps/search/?api=1&quer...
# 427  https://www.google.com/maps/search/?api=1&quer...
# 428  https://www.google.com/maps/search/?api=1&quer...
#
#                        coords  \
# 0    (49.2305035, 16.5337673)
# 1    (49.2333335, 16.5308843)
# 2    (49.2339446, 16.5343742)
# 3    (49.2609078, 16.5798162)
# 4    (49.2452964, 16.5818784)
# ..                        ...
# 424  (49.1925629, 16.6048872)
# 425  (49.1943746, 16.6047935)
# 426   (49.217818, 16.6207745)
# 427  (49.1932345, 16.6052392)
# 428  (49.1909134, 16.6222443)
#
#                                           neigbourhood
# 0    Bystrc, Brno, okres Brno-město, Jihomoravský k...
# 1    Bystrc, Brno, okres Brno-město, Jihomoravský k...
# 2    Bystrc, Brno, okres Brno-město, Jihomoravský k...
# 3    Ivanovice, Brno, okres Brno-město, Jihomoravsk...
# 4    Řečkovice, Brno, okres Brno-město, Jihomoravsk...
# ..                                                 ...
# 424  Staré Brno, Brno, okres Brno-město, Jihomoravs...
# 425  Město Brno, Brno, okres Brno-město, Jihomoravs...
# 426  Černá Pole, Brno, okres Brno-město, Jihomoravs...
# 427  Město Brno, Brno, okres Brno-město, Jihomoravs...
# 428  Trnitá, Brno, okres Brno-město, Jihomoravský k...
#
# [429 rows x 20 columns]

# %%
with open('non_cafes_final.txt', mode='r', encoding='utf-8') as file:
    non_cafes = file.readlines()

non_cafes
# Out:
# ['Pellegrini Caffe Restaurant\n',
#  'Bistro Franz\n',
#  'Špaček\n',
#  'PICCADILLY STORE & CAFFE\n',
#  'Šaškárna dětský park a kavárna\n',
#  'Fabrik Urban House\n',
#  'Za Zrcadlem\n',
#  'BarCafé Éléphant\n',
#  'Zahrádka Na Střeláku\n',
#  'Patisserie Větrník\n',
#  'SPOT\n',
#  'Sesamo\n',
#  'Cukrárna Větrník - Lidická\n',
#  'Cukrárna Větrník - Černá Pole\n',
#  'DuckBar\n',
#  'Bistro Hawránek\n',
#  'Turkish Supermarket, Halal Brno\n',
#  'Správné místo\n',
#  'Fruitisimo Campus\n',
#  'Café Tripoli\n',
#  'Red Piranha\n',
#  'Little Saigon Brno \n',
#  'TŘPYT\n',
#  'Cukrárna Větrník - NC Královo Pole\n',
#  'Sky Ice Bar\n',
#  'IQOS partner shop\n',
#  'Cukrárnička Husovice\n',
#  'Kobliha\n',
#  'Žádný Cukrbliky\n',
#  'Zmrzlinová kavárna - cukrárna\n',
#  '4Comfort\n',
#  'ZMRZKA fé\n',
#  'IKEA\n',
#  'Bed&Breakfast Klafé - je tam dvakrat s ruznym placeId a trochu jinam nazvem - možná jo\n',
#  'Přístav u Vodů\n',
#  'Monte Bú restaurant a steakhouse\n',
#  'Galerie Vaňkovka\n',
#  'Cukrárna Sweet Kiss\n',
#  'Marinada Store\n',
#  'JIP Svět potravin\n',
#  'Tereza Chocolate\n',
#  'Dilmah čaje\n',
#  'Cukrárna Cukrlenka\n',
#  'Cukrárna Eliška\n',
#  'La Vida Loca Cafe a Bar\n',
#  'BubbleTea, OXO TEA - kuličky, tapioka, čajové koktejly - Brno Nadraží\n',
#  'Klárabára Winecafé\n',
#  'AQUABAR\n',
#  'Čerpací stanice Shell Brno Řečkovice\n',
#  'Aida Cafe\n',
#  'Caffe Idea S. R. O.\n',
#  'Tutti Frutti\n',
#  'MADA ICE CREAM\n',
#  'ZANNAM Restaurant\n',
#  'Veg8Café\n',
#  'Vega Golf Club Cafe\n',
#  'Dance studio and cafe NO FEET\n',
#  'CUPCAKEKÁRNA\n',
#  'on billiards\n',
#  'Beach Bar Hříbek\n',
#  'coffee\n',
#  'Vietkong shop & chill\n',
#  'Viet Rice\n',
#  'U Pánů\n',
#  'Cukrárna kavárna Luna\n',
#  'Mlsná holka\n',
#  'Ema Cafe\n',
#  'Clark´s Brno Bake\n',
#  'Piazza Caffè\n',
#  'Zemanova kavárna a cukrárna\n',
#  'Dezert Café Joštova\n',
#  'Kinokavárna Brno\n',
#  'SORRY - we bake differently\n',
#  'Ikea Brno Cafe\n',
#  'Cukrárna Toffi\n',
#  'Cukrárna Park Lužánky']

# %%
non_cafes_cleaned = []

for cafe in non_cafes:
    cafe = cafe.strip()
    non_cafes_cleaned.append(cafe)

non_cafes_cleaned
# Out:
# ['Pellegrini Caffe Restaurant',
#  'Bistro Franz',
#  'Špaček',
#  'PICCADILLY STORE & CAFFE',
#  'Šaškárna dětský park a kavárna',
#  'Fabrik Urban House',
#  'Za Zrcadlem',
#  'BarCafé Éléphant',
#  'Zahrádka Na Střeláku',
#  'Patisserie Větrník',
#  'SPOT',
#  'Sesamo',
#  'Cukrárna Větrník - Lidická',
#  'Cukrárna Větrník - Černá Pole',
#  'DuckBar',
#  'Bistro Hawránek',
#  'Turkish Supermarket, Halal Brno',
#  'Správné místo',
#  'Fruitisimo Campus',
#  'Café Tripoli',
#  'Red Piranha',
#  'Little Saigon Brno',
#  'TŘPYT',
#  'Cukrárna Větrník - NC Královo Pole',
#  'Sky Ice Bar',
#  'IQOS partner shop',
#  'Cukrárnička Husovice',
#  'Kobliha',
#  'Žádný Cukrbliky',
#  'Zmrzlinová kavárna - cukrárna',
#  '4Comfort',
#  'ZMRZKA fé',
#  'IKEA',
#  'Bed&Breakfast Klafé - je tam dvakrat s ruznym placeId a trochu jinam nazvem - možná jo',
#  'Přístav u Vodů',
#  'Monte Bú restaurant a steakhouse',
#  'Galerie Vaňkovka',
#  'Cukrárna Sweet Kiss',
#  'Marinada Store',
#  'JIP Svět potravin',
#  'Tereza Chocolate',
#  'Dilmah čaje',
#  'Cukrárna Cukrlenka',
#  'Cukrárna Eliška',
#  'La Vida Loca Cafe a Bar',
#  'BubbleTea, OXO TEA - kuličky, tapioka, čajové koktejly - Brno Nadraží',
#  'Klárabára Winecafé',
#  'AQUABAR',
#  'Čerpací stanice Shell Brno Řečkovice',
#  'Aida Cafe',
#  'Caffe Idea S. R. O.',
#  'Tutti Frutti',
#  'MADA ICE CREAM',
#  'ZANNAM Restaurant',
#  'Veg8Café',
#  'Vega Golf Club Cafe',
#  'Dance studio and cafe NO FEET',
#  'CUPCAKEKÁRNA',
#  'on billiards',
#  'Beach Bar Hříbek',
#  'coffee',
#  'Vietkong shop & chill',
#  'Viet Rice',
#  'U Pánů',
#  'Cukrárna kavárna Luna',
#  'Mlsná holka',
#  'Ema Cafe',
#  'Clark´s Brno Bake',
#  'Piazza Caffè',
#  'Zemanova kavárna a cukrárna',
#  'Dezert Café Joštova',
#  'Kinokavárna Brno',
#  'SORRY - we bake differently',
#  'Ikea Brno Cafe',
#  'Cukrárna Toffi',
#  'Cukrárna Park Lužánky']

# %%
condition = (data['title'].isin(non_cafes_cleaned))

data_filtered = data[~condition]

data_filtered = data_filtered.set_index('placeId')
data_filtered
# Out:
#                              searchString                   title  \
# placeId
# ChIJe8xi1c-WEkcRZHdDHuo3j90       kavárna      Kavárna U Šimpanze
# ChIJhYGFpheXEkcRajb-rh-zrNw       kavárna                Křupkafé
# ChIJObMrvW-REkcRVzYBCe8TIb0       kavárna        Kavárna Dallmayr
# ChIJwamoDsSREkcR9p9fj5gJeFs       kavárna          Kafe a slanina
# ChIJ0ZsWTPKREkcR28TIEmN3wzM       kavárna  Pomlka Kavárna & Butik
# ...                                   ...                     ...
# ChIJUapYPACVEkcRo-3oyBeC9uI   coffee shop                  Mellow
# ChIJEWepNRmVEkcR-BUuY0XXNGU   coffee shop        Teamcaffe bistro
# ChIJS6BBUcaVEkcR4ZT1jabPeMo   coffee shop    tyjátr coffee & wine
# ChIJj5cikNKVEkcRiukU7AjL2ow  espresso bar        Patio Café & Bar
# ChIJS0FEsvmVEkcR9zM01uPpfjc  espresso bar    OC Nosreti - Café 52
#
#                              categoryName  \
# placeId
# ChIJe8xi1c-WEkcRZHdDHuo3j90   Coffee shop
# ChIJhYGFpheXEkcRajb-rh-zrNw   Coffee shop
# ChIJObMrvW-REkcRVzYBCe8TIb0          Cafe
# ChIJwamoDsSREkcR9p9fj5gJeFs   Coffee shop
# ChIJ0ZsWTPKREkcR28TIEmN3wzM   Coffee shop
# ...                                   ...
# ChIJUapYPACVEkcRo-3oyBeC9uI   Coffee shop
# ChIJEWepNRmVEkcR-BUuY0XXNGU   Coffee shop
# ChIJS6BBUcaVEkcR4ZT1jabPeMo   Coffee shop
# ChIJj5cikNKVEkcRiukU7AjL2ow  Espresso bar
# ChIJS0FEsvmVEkcR9zM01uPpfjc  Espresso bar
#
#                                                                        address  \
# placeId
# ChIJe8xi1c-WEkcRZHdDHuo3j90                       635 00, Brno-Bystrc, Czechia
# ChIJhYGFpheXEkcRajb-rh-zrNw  U Zoologické zahrady 147, 664 71 Brno-Bystrc, ...
# ChIJObMrvW-REkcRVzYBCe8TIb0  621 00, Hradecká 408/40, 621 00 Brno-Ivanovice...
# ChIJwamoDsSREkcR9p9fj5gJeFs  Böhmova 13, 621 00 Brno-Řečkovice a Mokrá Hora...
# ChIJ0ZsWTPKREkcR28TIEmN3wzM      Třešňová 330/2, 621 00 Brno-Medlánky, Czechia
# ...                                                                        ...
# ChIJUapYPACVEkcRo-3oyBeC9uI    Panská 393/6/602 00, 602 00 Brno-město, Czechia
# ChIJEWepNRmVEkcR-BUuY0XXNGU  Žerotínovo nám. 449/3, 602 00 Brno-střed-Veveř...
# ChIJS6BBUcaVEkcR4ZT1jabPeMo             Husova 14a, 602 00 Brno-střed, Czechia
# ChIJj5cikNKVEkcRiukU7AjL2ow              Husova 8A, 602 00 Brno-střed, Czechia
# ChIJS0FEsvmVEkcR9zM01uPpfjc         Křenová 409/52, 602 00 Brno-střed, Czechia
#
#                                                street  \
# placeId
# ChIJe8xi1c-WEkcRZHdDHuo3j90                    635 00
# ChIJhYGFpheXEkcRajb-rh-zrNw  U Zoologické zahrady 147
# ChIJObMrvW-REkcRVzYBCe8TIb0   621 00, Hradecká 408/40
# ChIJwamoDsSREkcR9p9fj5gJeFs                Böhmova 13
# ChIJ0ZsWTPKREkcR28TIEmN3wzM            Třešňová 330/2
# ...                                               ...
# ChIJUapYPACVEkcRo-3oyBeC9uI       Panská 393/6/602 00
# ChIJEWepNRmVEkcR-BUuY0XXNGU     Žerotínovo nám. 449/3
# ChIJS6BBUcaVEkcR4ZT1jabPeMo                Husova 14a
# ChIJj5cikNKVEkcRiukU7AjL2ow                 Husova 8A
# ChIJS0FEsvmVEkcR9zM01uPpfjc            Křenová 409/52
#
#                                                     city postalCode  \
# placeId
# ChIJe8xi1c-WEkcRZHdDHuo3j90                  Brno-Bystrc        NaN
# ChIJhYGFpheXEkcRajb-rh-zrNw                  Brno-Bystrc     664 71
# ChIJObMrvW-REkcRVzYBCe8TIb0               Brno-Ivanovice     621 00
# ChIJwamoDsSREkcR9p9fj5gJeFs  Brno-Řečkovice a Mokrá Hora     621 00
# ChIJ0ZsWTPKREkcR28TIEmN3wzM                Brno-Medlánky     621 00
# ...                                                  ...        ...
# ChIJUapYPACVEkcRo-3oyBeC9uI                   Brno-město     602 00
# ChIJEWepNRmVEkcR-BUuY0XXNGU            Brno-střed-Veveří     602 00
# ChIJS6BBUcaVEkcR4ZT1jabPeMo                   Brno-střed     602 00
# ChIJj5cikNKVEkcRiukU7AjL2ow                   Brno-střed     602 00
# ChIJS0FEsvmVEkcR9zM01uPpfjc                   Brno-střed     602 00
#
#                              claimThisBusiness  \
# placeId
# ChIJe8xi1c-WEkcRZHdDHuo3j90               True
# ChIJhYGFpheXEkcRajb-rh-zrNw              False
# ChIJObMrvW-REkcRVzYBCe8TIb0               True
# ChIJwamoDsSREkcR9p9fj5gJeFs              False
# ChIJ0ZsWTPKREkcR28TIEmN3wzM              False
# ...                                        ...
# ChIJUapYPACVEkcRo-3oyBeC9uI              False
# ChIJEWepNRmVEkcR-BUuY0XXNGU               True
# ChIJS6BBUcaVEkcR4ZT1jabPeMo              False
# ChIJj5cikNKVEkcRiukU7AjL2ow              False
# ChIJS0FEsvmVEkcR9zM01uPpfjc               True
#
#                                                            location  \
# placeId
# ChIJe8xi1c-WEkcRZHdDHuo3j90  {'lat': 49.2305035, 'lng': 16.5337673}
# ChIJhYGFpheXEkcRajb-rh-zrNw  {'lat': 49.2339446, 'lng': 16.5343742}
# ChIJObMrvW-REkcRVzYBCe8TIb0  {'lat': 49.2609078, 'lng': 16.5798162}
# ChIJwamoDsSREkcR9p9fj5gJeFs  {'lat': 49.2452964, 'lng': 16.5818784}
# ChIJ0ZsWTPKREkcR28TIEmN3wzM  {'lat': 49.2406722, 'lng': 16.5773899}
# ...                                                             ...
# ChIJUapYPACVEkcRo-3oyBeC9uI  {'lat': 49.1937682, 'lng': 16.6084204}
# ChIJEWepNRmVEkcR-BUuY0XXNGU  {'lat': 49.1986839, 'lng': 16.6040727}
# ChIJS6BBUcaVEkcR4ZT1jabPeMo  {'lat': 49.1943746, 'lng': 16.6047935}
# ChIJj5cikNKVEkcRiukU7AjL2ow  {'lat': 49.1932345, 'lng': 16.6052392}
# ChIJS0FEsvmVEkcR9zM01uPpfjc  {'lat': 49.1909134, 'lng': 16.6222443}
#
#                              totalScore  temporarilyClosed  \
# placeId
# ChIJe8xi1c-WEkcRZHdDHuo3j90         5.0              False
# ChIJhYGFpheXEkcRajb-rh-zrNw         4.8              False
# ChIJObMrvW-REkcRVzYBCe8TIb0         3.4              False
# ChIJwamoDsSREkcR9p9fj5gJeFs         4.8              False
# ChIJ0ZsWTPKREkcR28TIEmN3wzM         4.9              False
# ...                                 ...                ...
# ChIJUapYPACVEkcRo-3oyBeC9uI         4.7              False
# ChIJEWepNRmVEkcR-BUuY0XXNGU         5.0              False
# ChIJS6BBUcaVEkcR4ZT1jabPeMo         4.9               True
# ChIJj5cikNKVEkcRiukU7AjL2ow         5.0              False
# ChIJS0FEsvmVEkcR9zM01uPpfjc         4.3               True
#
#                                                            categories  \
# placeId
# ChIJe8xi1c-WEkcRZHdDHuo3j90                           ['Coffee shop']
# ChIJhYGFpheXEkcRajb-rh-zrNw                           ['Coffee shop']
# ChIJObMrvW-REkcRVzYBCe8TIb0                                  ['Cafe']
# ChIJwamoDsSREkcR9p9fj5gJeFs                           ['Coffee shop']
# ChIJ0ZsWTPKREkcR28TIEmN3wzM                           ['Coffee shop']
# ...                                                               ...
# ChIJUapYPACVEkcRo-3oyBeC9uI                           ['Coffee shop']
# ChIJEWepNRmVEkcR-BUuY0XXNGU                           ['Coffee shop']
# ChIJS6BBUcaVEkcR4ZT1jabPeMo  ['Coffee shop', 'Gastropub', 'Wine bar']
# ChIJj5cikNKVEkcRiukU7AjL2ow                          ['Espresso bar']
# ChIJS0FEsvmVEkcR9zM01uPpfjc                          ['Espresso bar']
#
#                                       cid  reviewsCount  \
# placeId
# ChIJe8xi1c-WEkcRZHdDHuo3j90  1.596504e+19             1
# ChIJhYGFpheXEkcRajb-rh-zrNw  1.590128e+19            16
# ChIJObMrvW-REkcRVzYBCe8TIb0  1.362820e+19            15
# ChIJwamoDsSREkcR9p9fj5gJeFs  6.591029e+18           149
# ChIJ0ZsWTPKREkcR28TIEmN3wzM  3.729956e+18            12
# ...                                   ...           ...
# ChIJUapYPACVEkcRo-3oyBeC9uI  1.635440e+19             7
# ChIJEWepNRmVEkcR-BUuY0XXNGU  7.292690e+18             1
# ChIJS6BBUcaVEkcR4ZT1jabPeMo  1.458964e+19            25
# ChIJj5cikNKVEkcRiukU7AjL2ow  1.014965e+19            17
# ChIJS0FEsvmVEkcR9zM01uPpfjc  3.998891e+18            15
#
#                                                            reviewsDistribution  \
# placeId
# ChIJe8xi1c-WEkcRZHdDHuo3j90  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# ChIJhYGFpheXEkcRajb-rh-zrNw  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# ChIJObMrvW-REkcRVzYBCe8TIb0  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# ChIJwamoDsSREkcR9p9fj5gJeFs  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# ChIJ0ZsWTPKREkcR28TIEmN3wzM  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# ...                                                                        ...
# ChIJUapYPACVEkcRo-3oyBeC9uI  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# ChIJEWepNRmVEkcR-BUuY0XXNGU  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# ChIJS6BBUcaVEkcR4ZT1jabPeMo  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# ChIJj5cikNKVEkcRiukU7AjL2ow  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# ChIJS0FEsvmVEkcR9zM01uPpfjc  {'oneStar': 2, 'twoStar': 0, 'threeStar': 0, '...
#
#                                                                   openingHours  \
# placeId
# ChIJe8xi1c-WEkcRZHdDHuo3j90  [{'day': 'Monday', 'hours': '10\u202fAM to 6\u...
# ChIJhYGFpheXEkcRajb-rh-zrNw  [{'day': 'Monday', 'hours': 'Closed'}, {'day':...
# ChIJObMrvW-REkcRVzYBCe8TIb0  [{'day': 'Monday', 'hours': '8:30\u202fAM to 8...
# ChIJwamoDsSREkcR9p9fj5gJeFs  [{'day': 'Monday', 'hours': '8\u202fAM to 6\u2...
# ChIJ0ZsWTPKREkcR28TIEmN3wzM  [{'day': 'Monday', 'hours': '8\u202fAM to 8\u2...
# ...                                                                        ...
# ChIJUapYPACVEkcRo-3oyBeC9uI  [{'day': 'Thursday', 'hours': '9\u202fAM to 7\...
# ChIJEWepNRmVEkcR-BUuY0XXNGU  [{'day': 'Thursday', 'hours': '6:30\u202fAM to...
# ChIJS6BBUcaVEkcR4ZT1jabPeMo                                                 []
# ChIJj5cikNKVEkcRiukU7AjL2ow  [{'day': 'Thursday', 'hours': '2 to 9\u202fPM'...
# ChIJS0FEsvmVEkcR9zM01uPpfjc                                                 []
#
#                                                                            url  \
# placeId
# ChIJe8xi1c-WEkcRZHdDHuo3j90  https://www.google.com/maps/search/?api=1&quer...
# ChIJhYGFpheXEkcRajb-rh-zrNw  https://www.google.com/maps/search/?api=1&quer...
# ChIJObMrvW-REkcRVzYBCe8TIb0  https://www.google.com/maps/search/?api=1&quer...
# ChIJwamoDsSREkcR9p9fj5gJeFs  https://www.google.com/maps/search/?api=1&quer...
# ChIJ0ZsWTPKREkcR28TIEmN3wzM  https://www.google.com/maps/search/?api=1&quer...
# ...                                                                        ...
# ChIJUapYPACVEkcRo-3oyBeC9uI  https://www.google.com/maps/search/?api=1&quer...
# ChIJEWepNRmVEkcR-BUuY0XXNGU  https://www.google.com/maps/search/?api=1&quer...
# ChIJS6BBUcaVEkcR4ZT1jabPeMo  https://www.google.com/maps/search/?api=1&quer...
# ChIJj5cikNKVEkcRiukU7AjL2ow  https://www.google.com/maps/search/?api=1&quer...
# ChIJS0FEsvmVEkcR9zM01uPpfjc  https://www.google.com/maps/search/?api=1&quer...
#
#                                                coords  \
# placeId
# ChIJe8xi1c-WEkcRZHdDHuo3j90  (49.2305035, 16.5337673)
# ChIJhYGFpheXEkcRajb-rh-zrNw  (49.2339446, 16.5343742)
# ChIJObMrvW-REkcRVzYBCe8TIb0  (49.2609078, 16.5798162)
# ChIJwamoDsSREkcR9p9fj5gJeFs  (49.2452964, 16.5818784)
# ChIJ0ZsWTPKREkcR28TIEmN3wzM  (49.2406722, 16.5773899)
# ...                                               ...
# ChIJUapYPACVEkcRo-3oyBeC9uI  (49.1937682, 16.6084204)
# ChIJEWepNRmVEkcR-BUuY0XXNGU  (49.1986839, 16.6040727)
# ChIJS6BBUcaVEkcR4ZT1jabPeMo  (49.1943746, 16.6047935)
# ChIJj5cikNKVEkcRiukU7AjL2ow  (49.1932345, 16.6052392)
# ChIJS0FEsvmVEkcR9zM01uPpfjc  (49.1909134, 16.6222443)
#
#                                                                   neigbourhood
# placeId
# ChIJe8xi1c-WEkcRZHdDHuo3j90  Bystrc, Brno, okres Brno-město, Jihomoravský k...
# ChIJhYGFpheXEkcRajb-rh-zrNw  Bystrc, Brno, okres Brno-město, Jihomoravský k...
# ChIJObMrvW-REkcRVzYBCe8TIb0  Ivanovice, Brno, okres Brno-město, Jihomoravsk...
# ChIJwamoDsSREkcR9p9fj5gJeFs  Řečkovice, Brno, okres Brno-město, Jihomoravsk...
# ChIJ0ZsWTPKREkcR28TIEmN3wzM  Medlánky, Brno, okres Brno-město, Jihomoravský...
# ...                                                                        ...
# ChIJUapYPACVEkcRo-3oyBeC9uI  Město Brno, Brno, okres Brno-město, Jihomoravs...
# ChIJEWepNRmVEkcR-BUuY0XXNGU  Veveří, Brno, okres Brno-město, Jihomoravský k...
# ChIJS6BBUcaVEkcR4ZT1jabPeMo  Město Brno, Brno, okres Brno-město, Jihomoravs...
# ChIJj5cikNKVEkcRiukU7AjL2ow  Město Brno, Brno, okres Brno-město, Jihomoravs...
# ChIJS0FEsvmVEkcR9zM01uPpfjc  Trnitá, Brno, okres Brno-město, Jihomoravský k...
#
# [354 rows x 19 columns]

# %%
data_filtered.shape
# Out:
# (354, 19)

# %%
data_filtered.to_csv('maps_google_scraped_final_dataset_V6.csv')
