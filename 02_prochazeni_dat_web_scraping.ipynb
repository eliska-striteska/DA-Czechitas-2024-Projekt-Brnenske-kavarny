# %% [markdown]
# Procházení dat v základně pročištěném datasetu

# %%
import pandas as pd
import json
import collections

# %%
cafes = pd.read_json('dataset_google-maps-extractor_Brno_kavarny_cleaned.json')
cafes.head()
# Out:
#   searchString               title categoryName  \
# 0      kavárna  Kavárna U Šimpanze  Coffee shop
# 1      kavárna              coffee  Coffee shop
# 2      kavárna            Křupkafé  Coffee shop
# 3      kavárna    Kavárna Dallmayr         Cafe
# 4      kavárna      Kafe a slanina  Coffee shop
#
#                                              address  \
# 0                       635 00, Brno-Bystrc, Czechia
# 1  U Zoologické zahrady 46, 635 00 Brno-Bystrc, C...
# 2  U Zoologické zahrady 147, 664 71 Brno-Bystrc, ...
# 3  621 00, Hradecká 408/40, 621 00 Brno-Ivanovice...
# 4  Böhmova 13, 621 00 Brno-Řečkovice a Mokrá Hora...
#
#                      street                         city postalCode  \
# 0                    635 00                  Brno-Bystrc       None
# 1   U Zoologické zahrady 46                  Brno-Bystrc     635 00
# 2  U Zoologické zahrady 147                  Brno-Bystrc     664 71
# 3   621 00, Hradecká 408/40               Brno-Ivanovice     621 00
# 4                Böhmova 13  Brno-Řečkovice a Mokrá Hora     621 00
#
#    claimThisBusiness                                location  totalScore  \
# 0               True  {'lat': 49.2305035, 'lng': 16.5337673}         5.0
# 1               True  {'lat': 49.2333335, 'lng': 16.5308843}         1.0
# 2              False  {'lat': 49.2339446, 'lng': 16.5343742}         4.8
# 3               True  {'lat': 49.2609078, 'lng': 16.5798162}         3.4
# 4              False  {'lat': 49.2452964, 'lng': 16.5818784}         4.8
#
#    temporarilyClosed                      placeId           cid  reviewsCount  \
# 0              False  ChIJe8xi1c-WEkcRZHdDHuo3j90  1.596504e+19             1
# 1              False  ChIJowGU1lKXEkcRhurHt6Lp8WA  6.985621e+18             1
# 2              False  ChIJhYGFpheXEkcRajb-rh-zrNw  1.590128e+19            16
# 3              False  ChIJObMrvW-REkcRVzYBCe8TIb0  1.362820e+19            15
# 4              False  ChIJwamoDsSREkcR9p9fj5gJeFs  6.591029e+18           149
#
#                                  reviewsDistribution  \
# 0  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# 1  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# 2  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# 3  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# 4  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
#
#                                         openingHours  \
# 0  [{'day': 'Monday', 'hours': '10 AM to 6 PM'}, ...
# 1                                                 []
# 2  [{'day': 'Monday', 'hours': 'Closed'}, {'day':...
# 3  [{'day': 'Monday', 'hours': '8:30 AM to 8 PM'}...
# 4  [{'day': 'Monday', 'hours': '8 AM to 6 PM'}, {...
#
#                                                  url
# 0  https://www.google.com/maps/search/?api=1&quer...
# 1  https://www.google.com/maps/search/?api=1&quer...
# 2  https://www.google.com/maps/search/?api=1&quer...
# 3  https://www.google.com/maps/search/?api=1&quer...
# 4  https://www.google.com/maps/search/?api=1&quer...

# %%
categories = cafes.groupby('categoryName')['title'].count().to_dict()

with open('list_of_categories.json', mode='w', encoding='utf-8') as output_file:
    json.dump(categories, output_file, indent=4, ensure_ascii=False)

# %%
cafes.columns
# Out:
# Index(['searchString', 'title', 'categoryName', 'address', 'street', 'city',
#        'postalCode', 'claimThisBusiness', 'location', 'totalScore',
#        'temporarilyClosed', 'placeId', 'cid', 'reviewsCount',
#        'reviewsDistribution', 'openingHours', 'url'],
#       dtype='object')

# %%
cafes.shape
# Out:
# (351, 17)

# %%
list_of_postalCodes = cafes['postalCode']
list_of_unique_postalCodes = cafes['postalCode'].unique()
print(list_of_unique_postalCodes)
# Out:
# [None '635 00' '664 71' '621 00' '612 00' '641 00' '613 00' '624 00'
#  '623 00' '638 00' '616 00' '614 00' '602 00' '639 00' '603 00' '625 00'
#  '642 00' '634 00' '619 00' '620 00' '637 00' '618 00' '611 80' '627 00'
#  '636 00' '628 00' '615 00' '664 42' '617 00' '601 77' '643 00']

# %%
list_of_postalCodes.info
# Out:
# <bound method Series.info of 0        None
# 1      635 00
# 2      664 71
# 3      621 00
# 4      621 00
#         ...
# 346    602 00
# 347    602 00
# 348    620 00
# 349    602 00
# 350    643 00
# Name: postalCode, Length: 351, dtype: object>

# %%
postalCode_counts = collections.Counter(list_of_postalCodes)
postalCode_counts
# Out:
# Counter({'602 00': 174,
#          '612 00': 27,
#          '635 00': 13,
#          '616 00': 12,
#          '625 00': 12,
#          '613 00': 11,
#          '614 00': 10,
#          '603 00': 10,
#          '621 00': 9,
#          '619 00': 8,
#          None: 7,
#          '639 00': 7,
#          '628 00': 6,
#          '638 00': 5,
#          '627 00': 5,
#          '615 00': 5,
#          '623 00': 4,
#          '620 00': 4,
#          '624 00': 3,
#          '637 00': 3,
#          '618 00': 3,
#          '636 00': 2,
#          '664 42': 2,
#          '617 00': 2,
#          '664 71': 1,
#          '641 00': 1,
#          '642 00': 1,
#          '634 00': 1,
#          '611 80': 1,
#          '601 77': 1,
#          '643 00': 1})

# %%
category_cafe = pd.read_json('dataset_google-maps-extractor_Brno_category_cafe_cleaned.json')
category_cafe.shape
# category_cafe
# Out:
# (146, 17)

# %%
category_cafe['categoryName'].unique()
# Out:
# array(['Cafe', 'Coffee shop', 'Espresso bar'], dtype=object)

# %%
not_cafe = category_cafe[category_cafe['categoryName'] != 'Cafe']
not_cafe = not_cafe[category_cafe['categoryName'] != 'Coffee shop'] 
not_cafe = not_cafe[category_cafe['categoryName'] != 'Espresso bar']
not_cafe
# Out:
# C:\Users\elstr\AppData\Local\Temp\ipykernel_20360\96691468.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   not_cafe = not_cafe[category_cafe['categoryName'] != 'Coffee shop']
# C:\Users\elstr\AppData\Local\Temp\ipykernel_20360\96691468.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   not_cafe = not_cafe[category_cafe['categoryName'] != 'Espresso bar']
# Empty DataFrame
# Columns: [searchString, title, categoryName, address, street, city, postalCode, claimThisBusiness, location, totalScore, temporarilyClosed, placeId, cid, reviewsCount, reviewsDistribution, openingHours, url]
# Index: []

# %%
category_coffee_shop = pd.read_json('dataset_google-maps-extractor_Brno_category_coffee_shop_cleaned.json')
category_coffee_shop.shape
category_coffee_shop.head()
# Out:
#   searchString               title categoryName  \
# 0  coffee shop  Stehlik Coffee Bar  Coffee shop
# 1  coffee shop  Poppy Beans Coffee  Coffee shop
# 2  coffee shop    But first coffee  Coffee shop
# 3  coffee shop        Little Italy  Coffee shop
# 4  coffee shop       Objekt coffee  Coffee shop
#
#                                              address           street  \
# 0      Křenová 52, 602 00 Brno-střed-Trnitá, Czechia       Křenová 52
# 1  Staňkova 360/8b, 602 00 Brno-Královo Pole-Pona...  Staňkova 360/8b
# 2        Jezuitská 13/11, 602 00 Brno-město, Czechia  Jezuitská 13/11
# 3   Grohova 102/3, 602 00 Brno-střed-Veveří, Czechia    Grohova 102/3
# 4          Říčanská 23, 641 00 Brno-Žebětín, Czechia      Říčanská 23
#
#                        city postalCode  claimThisBusiness  \
# 0         Brno-střed-Trnitá     602 00              False
# 1  Brno-Královo Pole-Ponava     602 00              False
# 2                Brno-město     602 00              False
# 3         Brno-střed-Veveří     602 00              False
# 4              Brno-Žebětín     641 00              False
#
#                                          location  totalScore  \
# 0          {'lat': 49.1908635, 'lng': 16.6227661}         4.9
# 1          {'lat': 49.2090291, 'lng': 16.6055302}         4.8
# 2          {'lat': 49.1971351, 'lng': 16.6106452}         5.0
# 3  {'lat': 49.2009637, 'lng': 16.599179499999998}         5.0
# 4          {'lat': 49.2179305, 'lng': 16.4974991}         4.5
#
#    temporarilyClosed                      placeId           cid  reviewsCount  \
# 0              False  ChIJR7YPVXCVEkcRgHMAIXgM3xM  1.431877e+18            68
# 1              False  ChIJIfLAqS-VEkcR1sRhaFAI0Aw  9.232471e+17           292
# 2              False  ChIJ89m0UMSVEkcRprGAhG14yuM  1.641406e+19            35
# 3              False  ChIJwd68iYOVEkcRttnaE9tcpxE  1.272088e+18             6
# 4              False  ChIJVcT8rQWXEkcRE2UzJmvSagM  2.462405e+17           150
#
#                                  reviewsDistribution  \
# 0  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# 1  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# 2  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# 3  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# 4  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
#
#                                         openingHours  \
# 0  [{'day': 'Thursday', 'hours': '8 AM to 4:30 PM...
# 1  [{'day': 'Thursday', 'hours': '8 AM to 8 PM'},...
# 2  [{'day': 'Thursday', 'hours': '7 AM to 6 PM'},...
# 3  [{'day': 'Thursday', 'hours': '9 AM to 1 PM, 2...
# 4  [{'day': 'Thursday', 'hours': '9 AM to 8 PM'},...
#
#                                                  url
# 0  https://www.google.com/maps/search/?api=1&quer...
# 1  https://www.google.com/maps/search/?api=1&quer...
# 2  https://www.google.com/maps/search/?api=1&quer...
# 3  https://www.google.com/maps/search/?api=1&quer...
# 4  https://www.google.com/maps/search/?api=1&quer...

# %%
category_coffee_shop['categoryName'].unique()
# Out:
# array(['Coffee shop', 'Espresso bar'], dtype=object)

# %%
not_cafe_2 = category_coffee_shop[category_coffee_shop['categoryName'] == 'Wholesale bakery']
not_cafe_2
# Out:
# Empty DataFrame
# Columns: [searchString, title, categoryName, address, street, city, postalCode, claimThisBusiness, location, totalScore, temporarilyClosed, placeId, cid, reviewsCount, reviewsDistribution, openingHours, url]
# Index: []

# %%
category_espresso_bar = pd.read_json('dataset_google-maps-extractor_Brno_category_espresso_bar_cleaned.json')
category_espresso_bar.shape
category_espresso_bar.head()
# Out:
#    searchString                                              title  \
# 0  espresso bar                         Gill's Coffee Espresso Bar
# 1  espresso bar                                 Punkt.espresso.bar
# 2  espresso bar  The Roses Coffee&Store - Specialty coffee Espr...
# 3  espresso bar                                       Vždycky kafe
# 4  espresso bar                                         Fresh Café
#
#    categoryName                                            address  \
# 0  Espresso bar    Veveří 456/9, 602 00 Brno-střed-Veveří, Czechia
# 1  Espresso bar  Štefánikova 131/61, 612 00 Brno-Královo Pole-P...
# 2  Espresso bar        Benešova 605/18, 602 00 Brno-město, Czechia
# 3  Espresso bar  Fryčajova 532/147, 614 00 Brno-Maloměřice a Ob...
# 4  Espresso bar  Makovského nám. 2, 616 00 Brno-Žabovřesky, Cze...
#
#                street                      city postalCode  claimThisBusiness  \
# 0        Veveří 456/9         Brno-střed-Veveří     602 00              False
# 1  Štefánikova 131/61  Brno-Královo Pole-Ponava     612 00              False
# 2     Benešova 605/18                Brno-město     602 00              False
# 3   Fryčajova 532/147  Brno-Maloměřice a Obřany     614 00              False
# 4   Makovského nám. 2           Brno-Žabovřesky     616 00               True
#
#                                  location  totalScore  temporarilyClosed  \
# 0  {'lat': 49.1992388, 'lng': 16.6024126}         4.7              False
# 1  {'lat': 49.2161208, 'lng': 16.5989587}         4.8              False
# 2  {'lat': 49.1927711, 'lng': 16.6132809}         4.9              False
# 3   {'lat': 49.235945, 'lng': 16.6440551}         4.8              False
# 4  {'lat': 49.2182964, 'lng': 16.5758641}         4.3              False
#
#                        placeId           cid  reviewsCount  \
# 0  ChIJtd4-GEWUEkcRp0mcwV5_GBk  1.808335e+18           151
# 1  ChIJg472j7WVEkcR4pLXHaHlaM0  1.480133e+19            61
# 2  ChIJpxgBpMWVEkcRg09Lu24nH1k  6.421895e+18           150
# 3  ChIJ11h9RCyTEkcRUrMLaukL5HI  8.278755e+18            32
# 4  ChIJK5kmQByUEkcR_qSV807ivro  1.345644e+19            82
#
#                                  reviewsDistribution  \
# 0  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# 1  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# 2  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# 3  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
# 4  {'oneStar': 0, 'twoStar': 0, 'threeStar': 0, '...
#
#                                         openingHours  \
# 0  [{'day': 'Thursday', 'hours': '8 AM to 5 PM'},...
# 1  [{'day': 'Thursday', 'hours': '8 AM to 6 PM'},...
# 2  [{'day': 'Thursday', 'hours': '7 AM to 7 PM'},...
# 3  [{'day': 'Thursday', 'hours': '1 to 10 PM'}, {...
# 4  [{'day': 'Thursday', 'hours': '7 AM to 6 PM'},...
#
#                                                  url
# 0  https://www.google.com/maps/search/?api=1&quer...
# 1  https://www.google.com/maps/search/?api=1&quer...
# 2  https://www.google.com/maps/search/?api=1&quer...
# 3  https://www.google.com/maps/search/?api=1&quer...
# 4  https://www.google.com/maps/search/?api=1&quer...

# %%
category_espresso_bar['categoryName'].unique()
# Out:
# array(['Espresso bar', 'Cafe', 'Coffee shop'], dtype=object)

# %%
not_cafe_3 = category_espresso_bar[category_espresso_bar['categoryName'] != 'Espresso bar']
not_cafe_3 = not_cafe_3[category_espresso_bar['categoryName'] != 'Cafe']
not_cafe_3 = not_cafe_3[category_espresso_bar['categoryName'] != 'Coffee shop']
not_cafe_3
# Out:
# C:\Users\elstr\AppData\Local\Temp\ipykernel_20360\3017041836.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   not_cafe_3 = not_cafe_3[category_espresso_bar['categoryName'] != 'Cafe']
# C:\Users\elstr\AppData\Local\Temp\ipykernel_20360\3017041836.py:3: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   not_cafe_3 = not_cafe_3[category_espresso_bar['categoryName'] != 'Coffee shop']
# Empty DataFrame
# Columns: [searchString, title, categoryName, address, street, city, postalCode, claimThisBusiness, location, totalScore, temporarilyClosed, placeId, cid, reviewsCount, reviewsDistribution, openingHours, url]
# Index: []
